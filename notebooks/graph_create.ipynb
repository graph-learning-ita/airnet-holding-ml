# %%
import pandas as pd
from dsc2024 import datasets

# %%
# %%time
df = datasets.get_train_dataset(raw_data=True)
# Out:
# CPU times: user 1.03 s, sys: 78.5 ms, total: 1.1 s
# Wall time: 1.68 s

# %%
len(df)
# Out:
# 211679

# %%
import networkx as nx

# %%
set(df['origem'])
# Out:
# {'SBBR',
#  'SBCF',
#  'SBCT',
#  'SBFL',
#  'SBGL',
#  'SBGR',
#  'SBKP',
#  'SBPA',
#  'SBRF',
#  'SBRJ',
#  'SBSP',
#  'SBSV'}

# %%
set(df['destino'])
# Out:
# {'SBBR',
#  'SBCF',
#  'SBCT',
#  'SBFL',
#  'SBGL',
#  'SBGR',
#  'SBKP',
#  'SBPA',
#  'SBRF',
#  'SBRJ',
#  'SBSP',
#  'SBSV'}

# %%
set(df['destino']) == set(df['origem'])
# Out:
# True

# %%
nodes = set(df['destino'])

# %%
number_of_nodes= len(nodes)

# %%
arcs = list(zip(df.origem,df.destino))

# %%
arcs
# Out:
# [('SBCF', 'SBFL'),
#  ('SBPA', 'SBFL'),
#  ('SBSP', 'SBCF'),
#  ('SBGR', 'SBCT'),
#  ('SBSP', 'SBSV'),
#  ('SBGR', 'SBPA'),
#  ('SBKP', 'SBBR'),
#  ('SBRF', 'SBGR'),
#  ('SBGR', 'SBPA'),
#  ('SBPA', 'SBGR'),
#  ('SBSP', 'SBCT'),
#  ('SBGR', 'SBGL'),
#  ('SBGR', 'SBBR'),
#  ('SBKP', 'SBPA'),
#  ('SBRJ', 'SBSV'),
#  ('SBSP', 'SBRF'),
#  ('SBRJ', 'SBBR'),
#  ('SBGR', 'SBRF'),
#  ('SBBR', 'SBSV'),
#  ('SBPA', 'SBKP'),
#  ('SBCF', 'SBBR'),
#  ('SBGR', 'SBCT'),
#  ('SBGR', 'SBSV'),
#  ('SBGR', 'SBRF'),
#  ('SBRJ', 'SBRF'),
#  ('SBGR', 'SBFL'),
#  ('SBKP', 'SBCT'),
#  ('SBRF', 'SBSV'),
#  ('SBCF', 'SBGR'),
#  ('SBGR', 'SBSV'),
#  ('SBKP', 'SBRF'),
#  ('SBCT', 'SBGR'),
#  ('SBKP', 'SBCF'),
#  ('SBGR', 'SBGL'),
#  ('SBCF', 'SBRF'),
#  ('SBPA', 'SBGR'),
#  ('SBKP', 'SBGL'),
#  ('SBRF', 'SBGR'),
#  ('SBGR', 'SBRF'),
#  ('SBBR', 'SBGR'),
#  ('SBKP', 'SBFL'),
#  ('SBCT', 'SBFL'),
#  ('SBRF', 'SBCF'),
#  ('SBRF', 'SBSP'),
#  ('SBRF', 'SBGR'),
#  ('SBRF', 'SBGL'),
#  ('SBSV', 'SBCF'),
#  ('SBRF', 'SBBR'),
#  ('SBRF', 'SBRJ'),
#  ('SBRF', 'SBKP'),
#  ('SBSV', 'SBSP'),
#  ('SBSV', 'SBGR'),
#  ('SBSV', 'SBSP'),
#  ('SBSV', 'SBRJ'),
#  ('SBGR', 'SBCF'),
#  ('SBBR', 'SBRJ'),
#  ('SBGL', 'SBGR'),
#  ('SBRF', 'SBBR'),
#  ('SBGR', 'SBRF'),
#  ('SBSV', 'SBSP'),
#  ('SBRF', 'SBGR'),
#  ('SBPA', 'SBSP'),
#  ('SBRF', 'SBSP'),
#  ('SBPA', 'SBBR'),
#  ('SBFL', 'SBGR'),
#  ('SBPA', 'SBCF'),
#  ('SBFL', 'SBCF'),
#  ('SBPA', 'SBKP'),
#  ('SBCT', 'SBSP'),
#  ('SBFL', 'SBKP'),
#  ('SBCF', 'SBSP'),
#  ('SBFL', 'SBBR'),
#  ('SBCT', 'SBCF'),
#  ('SBPA', 'SBGR'),
#  ('SBKP', 'SBRJ'),
#  ('SBPA', 'SBGR'),
#  ('SBBR', 'SBKP'),
#  ('SBBR', 'SBKP'),
#  ('SBFL', 'SBRJ'),
#  ('SBCF', 'SBBR'),
#  ('SBGL', 'SBKP'),
#  ('SBPA', 'SBRJ'),
#  ('SBRJ', 'SBGR'),
#  ('SBBR', 'SBSP'),
#  ('SBSV', 'SBRF'),
#  ('SBCT', 'SBKP'),
#  ('SBCT', 'SBKP'),
#  ('SBRJ', 'SBPA'),
#  ('SBFL', 'SBBR'),
#  ('SBRJ', 'SBSP'),
#  ('SBBR', 'SBCF'),
#  ('SBPA', 'SBRJ'),
#  ('SBKP', 'SBBR'),
#  ('SBRJ', 'SBBR'),
#  ('SBSP', 'SBSV'),
#  ('SBGR', 'SBFL'),
#  ('SBSP', 'SBBR'),
#  ('SBRF', 'SBSP'),
#  ('SBSP', 'SBBR'),
#  ('SBPA', 'SBSP'),
#  ('SBCT', 'SBBR'),
#  ('SBKP', 'SBCT'),
#  ('SBRJ', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBCF'),
#  ('SBCT', 'SBGR'),
#  ('SBBR', 'SBRJ'),
#  ('SBSV', 'SBSP'),
#  ('SBPA', 'SBKP'),
#  ('SBBR', 'SBSP'),
#  ('SBSP', 'SBCF'),
#  ('SBSV', 'SBGR'),
#  ('SBRJ', 'SBBR'),
#  ('SBSP', 'SBCF'),
#  ('SBGL', 'SBBR'),
#  ('SBKP', 'SBRJ'),
#  ('SBSP', 'SBPA'),
#  ('SBGR', 'SBBR'),
#  ('SBPA', 'SBCT'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBFL', 'SBPA'),
#  ('SBRJ', 'SBSP'),
#  ('SBRJ', 'SBCF'),
#  ('SBCF', 'SBKP'),
#  ('SBKP', 'SBSV'),
#  ('SBBR', 'SBGR'),
#  ('SBGR', 'SBCF'),
#  ('SBSP', 'SBRF'),
#  ('SBCF', 'SBBR'),
#  ('SBSP', 'SBCT'),
#  ('SBCT', 'SBRJ'),
#  ('SBRJ', 'SBSV'),
#  ('SBGR', 'SBBR'),
#  ('SBRJ', 'SBGR'),
#  ('SBSP', 'SBPA'),
#  ('SBGR', 'SBCT'),
#  ('SBGR', 'SBPA'),
#  ('SBBR', 'SBCF'),
#  ('SBCF', 'SBRJ'),
#  ('SBKP', 'SBCF'),
#  ('SBSP', 'SBBR'),
#  ('SBSP', 'SBRJ'),
#  ('SBPA', 'SBSP'),
#  ('SBKP', 'SBPA'),
#  ('SBSP', 'SBBR'),
#  ('SBRJ', 'SBBR'),
#  ('SBCT', 'SBSP'),
#  ('SBRJ', 'SBPA'),
#  ('SBPA', 'SBGR'),
#  ('SBCF', 'SBKP'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBCT'),
#  ('SBCF', 'SBGR'),
#  ('SBSP', 'SBRJ'),
#  ('SBGR', 'SBGL'),
#  ('SBBR', 'SBGR'),
#  ('SBCF', 'SBSP'),
#  ('SBBR', 'SBSP'),
#  ('SBGR', 'SBBR'),
#  ('SBSP', 'SBCF'),
#  ('SBGL', 'SBRF'),
#  ('SBSP', 'SBFL'),
#  ('SBKP', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBGR', 'SBPA'),
#  ('SBSP', 'SBRJ'),
#  ('SBKP', 'SBBR'),
#  ('SBGL', 'SBGR'),
#  ('SBGR', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBFL'),
#  ('SBSP', 'SBCT'),
#  ('SBFL', 'SBSP'),
#  ('SBFL', 'SBGR'),
#  ('SBSP', 'SBKP'),
#  ('SBCT', 'SBGR'),
#  ('SBGR', 'SBPA'),
#  ('SBRJ', 'SBSP'),
#  ('SBCT', 'SBPA'),
#  ('SBSP', 'SBPA'),
#  ('SBGR', 'SBFL'),
#  ('SBSP', 'SBRJ'),
#  ('SBKP', 'SBRJ'),
#  ('SBRJ', 'SBSP'),
#  ('SBGR', 'SBSV'),
#  ('SBCT', 'SBKP'),
#  ('SBSP', 'SBCF'),
#  ('SBCF', 'SBSP'),
#  ('SBBR', 'SBGL'),
#  ('SBCT', 'SBSP'),
#  ('SBCF', 'SBRJ'),
#  ('SBGR', 'SBRF'),
#  ('SBBR', 'SBSP'),
#  ('SBSP', 'SBSV'),
#  ('SBSP', 'SBRJ'),
#  ('SBSV', 'SBSP'),
#  ('SBRF', 'SBSP'),
#  ('SBCF', 'SBSV'),
#  ('SBRJ', 'SBKP'),
#  ('SBFL', 'SBGR'),
#  ('SBPA', 'SBCT'),
#  ('SBBR', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBBR'),
#  ('SBCF', 'SBSP'),
#  ('SBBR', 'SBRJ'),
#  ('SBSP', 'SBBR'),
#  ('SBCF', 'SBBR'),
#  ('SBFL', 'SBCT'),
#  ('SBBR', 'SBCT'),
#  ('SBGR', 'SBCT'),
#  ('SBKP', 'SBCT'),
#  ('SBRJ', 'SBGR'),
#  ('SBBR', 'SBKP'),
#  ('SBRJ', 'SBSP'),
#  ('SBPA', 'SBSP'),
#  ('SBGR', 'SBRJ'),
#  ('SBKP', 'SBBR'),
#  ('SBRJ', 'SBBR'),
#  ('SBRF', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBPA', 'SBFL'),
#  ('SBCF', 'SBCT'),
#  ('SBSP', 'SBPA'),
#  ('SBBR', 'SBRF'),
#  ('SBSP', 'SBRF'),
#  ('SBRJ', 'SBCF'),
#  ('SBCF', 'SBGR'),
#  ('SBRF', 'SBSV'),
#  ('SBPA', 'SBSP'),
#  ('SBSP', 'SBSV'),
#  ('SBGL', 'SBRF'),
#  ('SBBR', 'SBSV'),
#  ('SBRF', 'SBCF'),
#  ('SBBR', 'SBRJ'),
#  ('SBKP', 'SBFL'),
#  ('SBPA', 'SBRF'),
#  ('SBBR', 'SBPA'),
#  ('SBCF', 'SBRJ'),
#  ('SBSP', 'SBCF'),
#  ('SBCF', 'SBKP'),
#  ('SBBR', 'SBCF'),
#  ('SBPA', 'SBRJ'),
#  ('SBSP', 'SBRJ'),
#  ('SBCF', 'SBRF'),
#  ('SBRJ', 'SBKP'),
#  ('SBKP', 'SBSV'),
#  ('SBRF', 'SBGR'),
#  ('SBCT', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBGR'),
#  ('SBRF', 'SBRJ'),
#  ('SBFL', 'SBSP'),
#  ('SBCF', 'SBSP'),
#  ('SBKP', 'SBRJ'),
#  ('SBSV', 'SBCF'),
#  ('SBSP', 'SBPA'),
#  ('SBKP', 'SBRF'),
#  ('SBBR', 'SBRF'),
#  ('SBSV', 'SBRJ'),
#  ('SBBR', 'SBSP'),
#  ('SBFL', 'SBSP'),
#  ('SBKP', 'SBGL'),
#  ('SBSP', 'SBPA'),
#  ('SBRJ', 'SBSV'),
#  ('SBKP', 'SBPA'),
#  ('SBPA', 'SBSP'),
#  ('SBBR', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBRF'),
#  ('SBSP', 'SBFL'),
#  ('SBKP', 'SBCF'),
#  ('SBBR', 'SBKP'),
#  ('SBCT', 'SBRJ'),
#  ('SBBR', 'SBRF'),
#  ('SBSP', 'SBRF'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBCT', 'SBSP'),
#  ('SBGR', 'SBPA'),
#  ('SBSP', 'SBBR'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBCT'),
#  ('SBSV', 'SBKP'),
#  ('SBFL', 'SBGR'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBPA'),
#  ('SBRJ', 'SBSP'),
#  ('SBBR', 'SBRJ'),
#  ('SBSP', 'SBSV'),
#  ('SBRJ', 'SBPA'),
#  ('SBBR', 'SBPA'),
#  ('SBKP', 'SBCT'),
#  ('SBBR', 'SBGR'),
#  ('SBRJ', 'SBGR'),
#  ('SBGR', 'SBCT'),
#  ('SBBR', 'SBSP'),
#  ('SBBR', 'SBSP'),
#  ('SBSP', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBBR', 'SBSV'),
#  ('SBPA', 'SBGR'),
#  ('SBCF', 'SBGR'),
#  ('SBPA', 'SBRJ'),
#  ('SBFL', 'SBPA'),
#  ('SBSP', 'SBRJ'),
#  ('SBPA', 'SBSP'),
#  ('SBGR', 'SBCF'),
#  ('SBBR', 'SBKP'),
#  ('SBGR', 'SBFL'),
#  ('SBCT', 'SBGR'),
#  ('SBCT', 'SBCF'),
#  ('SBPA', 'SBGR'),
#  ('SBSP', 'SBCT'),
#  ('SBGR', 'SBGL'),
#  ('SBRJ', 'SBSP'),
#  ('SBRF', 'SBSP'),
#  ('SBCT', 'SBGR'),
#  ('SBCF', 'SBSP'),
#  ('SBCT', 'SBKP'),
#  ('SBSP', 'SBRF'),
#  ('SBPA', 'SBSV'),
#  ('SBSP', 'SBPA'),
#  ('SBRJ', 'SBCF'),
#  ('SBBR', 'SBCF'),
#  ('SBCT', 'SBPA'),
#  ('SBSP', 'SBRJ'),
#  ('SBFL', 'SBKP'),
#  ('SBGR', 'SBCF'),
#  ('SBSP', 'SBSV'),
#  ('SBRJ', 'SBSP'),
#  ('SBGR', 'SBBR'),
#  ('SBGR', 'SBSV'),
#  ('SBSV', 'SBRF'),
#  ('SBRJ', 'SBBR'),
#  ('SBBR', 'SBKP'),
#  ('SBSV', 'SBGR'),
#  ('SBBR', 'SBRJ'),
#  ('SBPA', 'SBSP'),
#  ('SBSP', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBRF', 'SBGR'),
#  ('SBPA', 'SBKP'),
#  ('SBGR', 'SBRF'),
#  ('SBSP', 'SBCF'),
#  ('SBRJ', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBGR', 'SBPA'),
#  ('SBFL', 'SBKP'),
#  ('SBCF', 'SBSP'),
#  ('SBSV', 'SBGR'),
#  ('SBKP', 'SBFL'),
#  ('SBBR', 'SBGR'),
#  ('SBKP', 'SBPA'),
#  ('SBSP', 'SBPA'),
#  ('SBGL', 'SBKP'),
#  ('SBKP', 'SBRJ'),
#  ('SBSV', 'SBSP'),
#  ('SBCF', 'SBKP'),
#  ('SBRJ', 'SBSP'),
#  ('SBKP', 'SBBR'),
#  ('SBRJ', 'SBSP'),
#  ('SBBR', 'SBRJ'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBBR'),
#  ('SBSV', 'SBSP'),
#  ('SBGR', 'SBRJ'),
#  ('SBRJ', 'SBSP'),
#  ('SBPA', 'SBSP'),
#  ('SBSV', 'SBRJ'),
#  ('SBSP', 'SBRJ'),
#  ('SBPA', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBCT', 'SBSP'),
#  ('SBKP', 'SBSV'),
#  ('SBSV', 'SBCF'),
#  ('SBSP', 'SBCT'),
#  ('SBPA', 'SBSP'),
#  ('SBRJ', 'SBKP'),
#  ('SBCT', 'SBKP'),
#  ('SBSP', 'SBSV'),
#  ('SBSP', 'SBFL'),
#  ('SBRJ', 'SBSP'),
#  ('SBCT', 'SBKP'),
#  ('SBGR', 'SBCT'),
#  ('SBPA', 'SBCT'),
#  ('SBCF', 'SBSV'),
#  ('SBSP', 'SBCT'),
#  ('SBCT', 'SBRJ'),
#  ('SBBR', 'SBSP'),
#  ('SBFL', 'SBGR'),
#  ('SBPA', 'SBKP'),
#  ('SBSP', 'SBSV'),
#  ('SBCT', 'SBGR'),
#  ('SBSP', 'SBCF'),
#  ('SBGR', 'SBCF'),
#  ('SBPA', 'SBSP'),
#  ('SBRF', 'SBGL'),
#  ('SBGL', 'SBGR'),
#  ('SBGR', 'SBPA'),
#  ('SBRJ', 'SBPA'),
#  ('SBCF', 'SBSP'),
#  ('SBRJ', 'SBCT'),
#  ('SBSP', 'SBRF'),
#  ('SBRJ', 'SBCT'),
#  ('SBCF', 'SBGR'),
#  ('SBGR', 'SBSV'),
#  ('SBGR', 'SBBR'),
#  ('SBCF', 'SBSV'),
#  ('SBPA', 'SBRJ'),
#  ('SBCF', 'SBBR'),
#  ('SBSP', 'SBBR'),
#  ('SBCF', 'SBRJ'),
#  ('SBGR', 'SBRJ'),
#  ('SBGR', 'SBPA'),
#  ('SBRF', 'SBCF'),
#  ('SBRJ', 'SBGR'),
#  ('SBSP', 'SBRJ'),
#  ('SBCF', 'SBGR'),
#  ('SBRF', 'SBSV'),
#  ('SBSP', 'SBRF'),
#  ('SBCF', 'SBSP'),
#  ('SBPA', 'SBGR'),
#  ('SBRJ', 'SBCT'),
#  ('SBBR', 'SBSV'),
#  ('SBGR', 'SBRF'),
#  ('SBFL', 'SBKP'),
#  ('SBRJ', 'SBSP'),
#  ('SBRJ', 'SBFL'),
#  ('SBSP', 'SBPA'),
#  ('SBRF', 'SBKP'),
#  ('SBSP', 'SBPA'),
#  ('SBFL', 'SBGR'),
#  ('SBBR', 'SBRJ'),
#  ('SBPA', 'SBSP'),
#  ('SBKP', 'SBGL'),
#  ('SBRF', 'SBRJ'),
#  ('SBSP', 'SBRF'),
#  ('SBPA', 'SBGR'),
#  ('SBSP', 'SBSV'),
#  ('SBCT', 'SBSP'),
#  ('SBKP', 'SBCF'),
#  ('SBGR', 'SBRF'),
#  ('SBKP', 'SBBR'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBKP', 'SBPA'),
#  ('SBRF', 'SBGR'),
#  ('SBCT', 'SBSP'),
#  ('SBSV', 'SBSP'),
#  ('SBCF', 'SBRF'),
#  ('SBRF', 'SBSP'),
#  ('SBKP', 'SBFL'),
#  ('SBRJ', 'SBKP'),
#  ('SBFL', 'SBSP'),
#  ('SBSP', 'SBFL'),
#  ('SBCF', 'SBSP'),
#  ('SBKP', 'SBSV'),
#  ('SBBR', 'SBRJ'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBRF'),
#  ('SBSP', 'SBCT'),
#  ('SBRJ', 'SBBR'),
#  ('SBKP', 'SBRF'),
#  ('SBCT', 'SBPA'),
#  ('SBSP', 'SBFL'),
#  ('SBBR', 'SBKP'),
#  ('SBKP', 'SBRJ'),
#  ('SBRF', 'SBSP'),
#  ('SBSP', 'SBSV'),
#  ('SBKP', 'SBCT'),
#  ('SBCT', 'SBCF'),
#  ('SBSV', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBGL', 'SBRF'),
#  ('SBPA', 'SBRJ'),
#  ('SBGR', 'SBRJ'),
#  ('SBRJ', 'SBGR'),
#  ('SBCF', 'SBPA'),
#  ('SBPA', 'SBGR'),
#  ('SBSP', 'SBSV'),
#  ('SBRJ', 'SBSP'),
#  ('SBSV', 'SBSP'),
#  ('SBCT', 'SBRJ'),
#  ('SBRJ', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBPA', 'SBKP'),
#  ('SBPA', 'SBSP'),
#  ('SBBR', 'SBGR'),
#  ('SBSV', 'SBPA'),
#  ('SBBR', 'SBCF'),
#  ('SBGR', 'SBSV'),
#  ('SBGR', 'SBCF'),
#  ('SBSP', 'SBRJ'),
#  ('SBCF', 'SBKP'),
#  ('SBSP', 'SBCT'),
#  ('SBGL', 'SBKP'),
#  ('SBSV', 'SBRJ'),
#  ('SBSV', 'SBRF'),
#  ('SBBR', 'SBSP'),
#  ('SBSP', 'SBCF'),
#  ('SBSP', 'SBSV'),
#  ('SBRJ', 'SBSP'),
#  ('SBGR', 'SBGL'),
#  ('SBSV', 'SBBR'),
#  ('SBCF', 'SBSP'),
#  ('SBSP', 'SBPA'),
#  ('SBPA', 'SBRJ'),
#  ('SBKP', 'SBCF'),
#  ('SBRJ', 'SBPA'),
#  ('SBSV', 'SBKP'),
#  ('SBKP', 'SBCT'),
#  ('SBSV', 'SBSP'),
#  ('SBGR', 'SBPA'),
#  ('SBSV', 'SBRF'),
#  ('SBGR', 'SBCT'),
#  ('SBRJ', 'SBSP'),
#  ('SBSV', 'SBGR'),
#  ('SBGR', 'SBRF'),
#  ('SBFL', 'SBKP'),
#  ('SBFL', 'SBSP'),
#  ('SBRF', 'SBGR'),
#  ('SBKP', 'SBPA'),
#  ('SBPA', 'SBCT'),
#  ('SBCF', 'SBGR'),
#  ('SBRJ', 'SBBR'),
#  ('SBSP', 'SBCF'),
#  ('SBRJ', 'SBBR'),
#  ('SBFL', 'SBRJ'),
#  ('SBPA', 'SBSP'),
#  ('SBBR', 'SBKP'),
#  ('SBGR', 'SBRJ'),
#  ('SBSP', 'SBPA'),
#  ('SBGR', 'SBFL'),
#  ('SBSV', 'SBSP'),
#  ('SBFL', 'SBSP'),
#  ('SBGR', 'SBGL'),
#  ('SBGL', 'SBGR'),
#  ('SBKP', 'SBRJ'),
#  ('SBCT', 'SBRJ'),
#  ('SBCT', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBSP', 'SBPA'),
#  ('SBGR', 'SBCT'),
#  ('SBPA', 'SBGR'),
#  ('SBCT', 'SBRJ'),
#  ('SBPA', 'SBBR'),
#  ('SBRF', 'SBSP'),
#  ('SBPA', 'SBKP'),
#  ('SBGR', 'SBCF'),
#  ('SBRF', 'SBBR'),
#  ('SBSV', 'SBSP'),
#  ('SBSP', 'SBFL'),
#  ('SBRJ', 'SBSP'),
#  ('SBPA', 'SBKP'),
#  ('SBCT', 'SBGR'),
#  ('SBGR', 'SBRJ'),
#  ('SBSP', 'SBRJ'),
#  ('SBCF', 'SBGR'),
#  ('SBSP', 'SBRF'),
#  ('SBRJ', 'SBSP'),
#  ('SBRJ', 'SBCF'),
#  ('SBFL', 'SBKP'),
#  ('SBGR', 'SBSV'),
#  ('SBCT', 'SBSP'),
#  ('SBSP', 'SBBR'),
#  ('SBKP', 'SBCF'),
#  ('SBRF', 'SBGR'),
#  ('SBKP', 'SBPA'),
#  ('SBSP', 'SBFL'),
#  ('SBBR', 'SBRJ'),
#  ('SBKP', 'SBBR'),
#  ('SBSP', 'SBRJ'),
#  ('SBRF', 'SBGR'),
#  ('SBRJ', 'SBKP'),
#  ('SBGL', 'SBGR'),
#  ('SBGR', 'SBCT'),
#  ('SBSP', 'SBCF'),
#  ('SBRF', 'SBSP'),
#  ('SBCF', 'SBSV'),
#  ('SBSP', 'SBCF'),
#  ('SBRJ', 'SBSV'),
#  ('SBRJ', 'SBBR'),
#  ('SBRJ', 'SBCT'),
#  ('SBSV', 'SBBR'),
#  ('SBGR', 'SBPA'),
#  ('SBSV', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBCT'),
#  ('SBCT', 'SBKP'),
#  ('SBGR', 'SBBR'),
#  ('SBSP', 'SBBR'),
#  ('SBSP', 'SBPA'),
#  ('SBCF', 'SBBR'),
#  ('SBRF', 'SBKP'),
#  ('SBKP', 'SBRJ'),
#  ('SBRF', 'SBSP'),
#  ('SBRJ', 'SBSV'),
#  ('SBSV', 'SBGR'),
#  ('SBGL', 'SBGR'),
#  ('SBCF', 'SBSP'),
#  ('SBCT', 'SBBR'),
#  ('SBCF', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBPA', 'SBSP'),
#  ('SBFL', 'SBSP'),
#  ('SBCF', 'SBSV'),
#  ('SBCT', 'SBPA'),
#  ('SBRF', 'SBBR'),
#  ('SBSP', 'SBCT'),
#  ('SBSP', 'SBRJ'),
#  ('SBRF', 'SBCF'),
#  ('SBSV', 'SBBR'),
#  ('SBGR', 'SBRJ'),
#  ('SBCF', 'SBSP'),
#  ('SBGR', 'SBCF'),
#  ('SBCF', 'SBGR'),
#  ('SBRJ', 'SBSP'),
#  ('SBRF', 'SBSV'),
#  ('SBPA', 'SBKP'),
#  ('SBCF', 'SBBR'),
#  ('SBCF', 'SBSP'),
#  ('SBCT', 'SBSP'),
#  ('SBGR', 'SBRF'),
#  ('SBCF', 'SBRJ'),
#  ('SBPA', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBKP'),
#  ('SBPA', 'SBBR'),
#  ('SBCT', 'SBGR'),
#  ('SBKP', 'SBFL'),
#  ('SBSV', 'SBSP'),
#  ('SBPA', 'SBFL'),
#  ('SBRJ', 'SBSP'),
#  ('SBPA', 'SBCF'),
#  ('SBBR', 'SBRJ'),
#  ('SBFL', 'SBGR'),
#  ('SBSV', 'SBSP'),
#  ('SBKP', 'SBPA'),
#  ('SBRJ', 'SBBR'),
#  ('SBSP', 'SBBR'),
#  ('SBBR', 'SBRJ'),
#  ('SBKP', 'SBGL'),
#  ('SBRF', 'SBSV'),
#  ('SBCF', 'SBRJ'),
#  ('SBSP', 'SBPA'),
#  ('SBRJ', 'SBSP'),
#  ('SBKP', 'SBCT'),
#  ('SBRF', 'SBRJ'),
#  ('SBBR', 'SBGR'),
#  ('SBCF', 'SBBR'),
#  ('SBCT', 'SBGR'),
#  ('SBRJ', 'SBGR'),
#  ('SBGL', 'SBBR'),
#  ('SBKP', 'SBBR'),
#  ('SBFL', 'SBSP'),
#  ('SBKP', 'SBRJ'),
#  ('SBRJ', 'SBSP'),
#  ('SBKP', 'SBCF'),
#  ('SBRF', 'SBBR'),
#  ('SBGR', 'SBPA'),
#  ('SBBR', 'SBSP'),
#  ('SBKP', 'SBBR'),
#  ('SBRJ', 'SBGR'),
#  ('SBCF', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBPA', 'SBGR'),
#  ('SBRJ', 'SBSP'),
#  ('SBCF', 'SBRJ'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBBR'),
#  ('SBGR', 'SBBR'),
#  ('SBCF', 'SBGR'),
#  ('SBGR', 'SBPA'),
#  ('SBCT', 'SBSP'),
#  ('SBRJ', 'SBSP'),
#  ('SBPA', 'SBCT'),
#  ('SBSP', 'SBRJ'),
#  ('SBCF', 'SBKP'),
#  ('SBRJ', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBFL'),
#  ('SBSP', 'SBCF'),
#  ('SBKP', 'SBCF'),
#  ('SBBR', 'SBKP'),
#  ('SBKP', 'SBRJ'),
#  ('SBRJ', 'SBCF'),
#  ('SBRJ', 'SBSP'),
#  ('SBGL', 'SBGR'),
#  ('SBKP', 'SBGL'),
#  ('SBSP', 'SBCF'),
#  ('SBBR', 'SBSP'),
#  ('SBSV', 'SBCF'),
#  ('SBSP', 'SBCT'),
#  ('SBRJ', 'SBGR'),
#  ('SBSP', 'SBRJ'),
#  ('SBCT', 'SBRJ'),
#  ('SBSP', 'SBCF'),
#  ('SBCF', 'SBGR'),
#  ('SBBR', 'SBCF'),
#  ('SBSP', 'SBRJ'),
#  ('SBKP', 'SBCT'),
#  ('SBSP', 'SBRJ'),
#  ('SBGR', 'SBRJ'),
#  ('SBPA', 'SBKP'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBKP'),
#  ('SBCT', 'SBSP'),
#  ('SBCT', 'SBSP'),
#  ('SBGR', 'SBCF'),
#  ('SBSP', 'SBCT'),
#  ('SBFL', 'SBPA'),
#  ('SBSP', 'SBRJ'),
#  ('SBKP', 'SBRJ'),
#  ('SBGR', 'SBCT'),
#  ('SBCT', 'SBGR'),
#  ('SBSP', 'SBRJ'),
#  ('SBSP', 'SBCF'),
#  ('SBSP', 'SBRJ'),
#  ('SBSP', 'SBRJ'),
#  ('SBGR', 'SBRJ'),
#  ('SBPA', 'SBGR'),
#  ('SBGR', 'SBGL'),
#  ('SBRJ', 'SBSP'),
#  ('SBCF', 'SBSP'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBCT'),
#  ('SBRF', 'SBGR'),
#  ('SBBR', 'SBGR'),
#  ('SBCF', 'SBSP'),
#  ('SBSP', 'SBFL'),
#  ('SBSP', 'SBBR'),
#  ('SBCF', 'SBRJ'),
#  ('SBGL', 'SBKP'),
#  ('SBBR', 'SBCT'),
#  ('SBPA', 'SBGR'),
#  ('SBCF', 'SBSP'),
#  ('SBRJ', 'SBFL'),
#  ('SBBR', 'SBKP'),
#  ('SBGR', 'SBRJ'),
#  ('SBBR', 'SBFL'),
#  ('SBGR', 'SBRJ'),
#  ('SBRJ', 'SBKP'),
#  ('SBCT', 'SBKP'),
#  ('SBBR', 'SBPA'),
#  ('SBGR', 'SBRJ'),
#  ('SBCF', 'SBKP'),
#  ('SBSP', 'SBCF'),
#  ('SBBR', 'SBGL'),
#  ('SBCF', 'SBCT'),
#  ('SBGR', 'SBFL'),
#  ('SBSP', 'SBSV'),
#  ('SBRJ', 'SBCT'),
#  ('SBBR', 'SBCF'),
#  ('SBGR', 'SBBR'),
#  ('SBCF', 'SBGR'),
#  ('SBGR', 'SBPA'),
#  ('SBCF', 'SBSV'),
#  ('SBKP', 'SBRJ'),
#  ('SBPA', 'SBFL'),
#  ('SBGR', 'SBCT'),
#  ('SBRJ', 'SBBR'),
#  ('SBCF', 'SBFL'),
#  ('SBSP', 'SBCF'),
#  ('SBCT', 'SBPA'),
#  ('SBGR', 'SBCF'),
#  ('SBGR', 'SBGL'),
#  ('SBSP', 'SBPA'),
#  ('SBGR', 'SBPA'),
#  ('SBGR', 'SBRF'),
#  ('SBRJ', 'SBPA'),
#  ('SBCF', 'SBGR'),
#  ('SBGR', 'SBSV'),
#  ('SBRJ', 'SBPA'),
#  ('SBGR', 'SBGL'),
#  ('SBGR', 'SBPA'),
#  ('SBRJ', 'SBGR'),
#  ('SBSP', 'SBBR'),
#  ('SBRJ', 'SBBR'),
#  ('SBKP', 'SBCF'),
#  ('SBRJ', 'SBSV'),
#  ('SBGR', 'SBCF'),
#  ('SBBR', 'SBCF'),
#  ('SBSP', 'SBRJ'),
#  ('SBRJ', 'SBRF'),
#  ('SBCF', 'SBBR'),
#  ('SBKP', 'SBBR'),
#  ('SBSP', 'SBRF'),
#  ('SBGR', 'SBCT'),
#  ('SBGR', 'SBCT'),
#  ('SBKP', 'SBCT'),
#  ('SBSV', 'SBGR'),
#  ('SBGR', 'SBFL'),
#  ('SBKP', 'SBRF'),
#  ('SBGR', 'SBRF'),
#  ('SBCF', 'SBRF'),
#  ('SBGR', 'SBBR'),
#  ('SBGR', 'SBSV'),
#  ('SBCF', 'SBPA'),
#  ('SBKP', 'SBPA'),
#  ('SBPA', 'SBRF'),
#  ('SBPA', 'SBGR'),
#  ('SBGR', 'SBGL'),
#  ('SBKP', 'SBGL'),
#  ('SBGR', 'SBRF'),
#  ('SBKP', 'SBSV'),
#  ('SBGR', 'SBPA'),
#  ('SBKP', 'SBFL'),
#  ('SBGR', 'SBRF'),
#  ('SBFL', 'SBPA'),
#  ('SBRF', 'SBGR'),
#  ('SBRF', 'SBPA'),
#  ('SBRF', 'SBCF'),
#  ('SBRF', 'SBSP'),
#  ('SBRF', 'SBSP'),
#  ('SBSV', 'SBKP'),
#  ('SBRF', 'SBGR'),
#  ('SBRF', 'SBKP'),
#  ('SBSV', 'SBCF'),
#  ('SBGR', 'SBPA'),
#  ('SBRF', 'SBBR'),
#  ('SBRF', 'SBRJ'),
#  ('SBSV', 'SBSP'),
#  ('SBSV', 'SBSP'),
#  ('SBBR', 'SBGR'),
#  ('SBSV', 'SBRJ'),
#  ('SBSV', 'SBGR'),
#  ('SBRF', 'SBGR'),
#  ('SBGR', 'SBCF'),
#  ('SBGL', 'SBGR'),
#  ('SBCT', 'SBGR'),
#  ('SBBR', 'SBRJ'),
#  ('SBGR', 'SBRF'),
#  ('SBSV', 'SBSP'),
#  ('SBGR', 'SBKP'),
#  ('SBCF', 'SBGR'),
#  ('SBPA', 'SBBR'),
#  ('SBRF', 'SBGR'),
#  ('SBFL', 'SBSP'),
#  ('SBFL', 'SBGR'),
#  ('SBCF', 'SBSP'),
#  ('SBPA', 'SBSP'),
#  ('SBFL', 'SBBR'),
#  ('SBPA', 'SBGR'),
#  ('SBPA', 'SBKP'),
#  ('SBCT', 'SBBR'),
#  ('SBFL', 'SBKP'),
#  ('SBCF', 'SBBR'),
#  ('SBPA', 'SBCF'),
#  ('SBCF', 'SBSP'),
#  ('SBBR', 'SBSP'),
#  ('SBFL', 'SBBR'),
#  ('SBCT', 'SBCF'),
#  ('SBPA', 'SBBR'),
#  ('SBPA', 'SBGR'),
#  ('SBBR', 'SBKP'),
#  ('SBKP', 'SBSV'),
#  ('SBCF', 'SBBR'),
#  ('SBPA', 'SBCT'),
#  ('SBGL', 'SBKP'),
#  ('SBRJ', 'SBGR'),
#  ('SBBR', 'SBSP'),
#  ('SBPA', 'SBGR'),
#  ('SBRJ', 'SBPA'),
#  ('SBBR', 'SBCF'),
#  ('SBKP', 'SBBR'),
#  ('SBSP', 'SBBR'),
#  ('SBRJ', 'SBBR'),
#  ('SBPA', 'SBRJ'),
#  ('SBFL', 'SBRJ'),
#  ('SBSV', 'SBGR'),
#  ('SBSP', 'SBSV'),
#  ('SBPA', 'SBRJ'),
#  ('SBCF', 'SBSP'),
#  ('SBCF', 'SBSP'),
#  ('SBSP', 'SBBR'),
#  ('SBRJ', 'SBSP'),
#  ('SBCT', 'SBBR'),
#  ('SBSP', 'SBCF'),
#  ('SBRJ', 'SBKP'),
#  ('SBCT', 'SBKP'),
#  ('SBRF', 'SBSP'),
#  ('SBRJ', 'SBCF'),
#  ('SBCF', 'SBBR'),
#  ('SBSP', 'SBCF'),
#  ('SBBR', 'SBRJ'),
#  ('SBGR', 'SBCF'),
#  ('SBCF', 'SBKP'),
#  ('SBPA', 'SBSP'),
#  ('SBKP', 'SBCT'),
#  ('SBCF', 'SBGR'),
#  ('SBPA', 'SBKP'),
#  ('SBKP', 'SBCF'),
#  ('SBGL', 'SBBR'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBPA'),
#  ('SBKP', 'SBRJ'),
#  ('SBGR', 'SBBR'),
#  ('SBRJ', 'SBBR'),
#  ('SBRJ', 'SBSV'),
#  ('SBRJ', 'SBCF'),
#  ('SBCF', 'SBRJ'),
#  ('SBSP', 'SBRF'),
#  ('SBBR', 'SBGR'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBSV'),
#  ('SBCT', 'SBRJ'),
#  ('SBRJ', 'SBGR'),
#  ('SBKP', 'SBBR'),
#  ('SBBR', 'SBCF'),
#  ('SBSP', 'SBPA'),
#  ('SBGR', 'SBBR'),
#  ('SBSP', 'SBRJ'),
#  ('SBGR', 'SBCT'),
#  ('SBSP', 'SBBR'),
#  ('SBSP', 'SBBR'),
#  ('SBRJ', 'SBPA'),
#  ('SBSP', 'SBCT'),
#  ('SBKP', 'SBPA'),
#  ('SBSP', 'SBRJ'),
#  ('SBCF', 'SBKP'),
#  ('SBCF', 'SBSV'),
#  ('SBGL', 'SBGR'),
#  ('SBGR', 'SBGL'),
#  ('SBRJ', 'SBBR'),
#  ('SBPA', 'SBGR'),
#  ('SBBR', 'SBGR'),
#  ('SBCF', 'SBGR'),
#  ('SBKP', 'SBCF'),
#  ('SBGR', 'SBPA'),
#  ('SBBR', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBGL', 'SBRF'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBFL'),
#  ('SBGR', 'SBCF'),
#  ('SBFL', 'SBGR'),
#  ('SBSP', 'SBCF'),
#  ('SBGR', 'SBBR'),
#  ('SBSP', 'SBCT'),
#  ('SBCT', 'SBGR'),
#  ('SBGR', 'SBCT'),
#  ('SBGR', 'SBPA'),
#  ('SBFL', 'SBSP'),
#  ('SBSP', 'SBRJ'),
#  ('SBSP', 'SBPA'),
#  ('SBSP', 'SBPA'),
#  ('SBPA', 'SBRF'),
#  ('SBCT', 'SBPA'),
#  ('SBGR', 'SBFL'),
#  ('SBKP', 'SBCF'),
#  ('SBGR', 'SBSV'),
#  ('SBBR', 'SBGL'),
#  ('SBCF', 'SBRJ'),
#  ('SBRF', 'SBSP'),
#  ('SBRJ', 'SBGR'),
#  ('SBCF', 'SBSV'),
#  ('SBCF', 'SBCT'),
#  ('SBSP', 'SBRJ'),
#  ('SBGR', 'SBRF'),
#  ('SBKP', 'SBCT'),
#  ('SBBR', 'SBRJ'),
#  ('SBSP', 'SBRJ'),
#  ('SBSP', 'SBSV'),
#  ('SBFL', 'SBCT'),
#  ('SBSP', 'SBBR'),
#  ('SBCF', 'SBBR'),
#  ('SBPA', 'SBCT'),
#  ('SBKP', 'SBPA'),
#  ('SBGR', 'SBRF'),
#  ('SBKP', 'SBBR'),
#  ('SBRJ', 'SBKP'),
#  ('SBCT', 'SBKP'),
#  ('SBKP', 'SBBR'),
#  ('SBRJ', 'SBSP'),
#  ('SBCF', 'SBSP'),
#  ('SBRF', 'SBSV'),
#  ('SBPA', 'SBSP'),
#  ('SBRJ', 'SBSP'),
#  ('SBRF', 'SBKP'),
#  ('SBGR', 'SBCF'),
#  ('SBBR', 'SBCT'),
#  ('SBPA', 'SBFL'),
#  ('SBBR', 'SBRF'),
#  ('SBRJ', 'SBSP'),
#  ('SBSP', 'SBCF'),
#  ('SBGR', 'SBRJ'),
#  ('SBSP', 'SBPA'),
#  ('SBCF', 'SBGR'),
#  ('SBBR', 'SBSP'),
#  ('SBSP', 'SBRF'),
#  ('SBSP', 'SBSV'),
#  ('SBCF', 'SBSP'),
#  ('SBBR', 'SBSP'),
#  ('SBRJ', 'SBBR'),
#  ('SBPA', 'SBSP'),
#  ('SBGL', 'SBRF'),
#  ('SBBR', 'SBRJ'),
#  ...]

# %%
arcs_freq= {x : arcs.count(x) for x in set(arcs)}

# %%
number_of_edges= len(arcs_freq)

# %%
number_of_nodes*(number_of_nodes-1)
# Out:
# 132

# %%
number_of_edges
# Out:
# 129

# %%
edges= [tuple(list(tup)+[val] )     for tup,val in zip(arcs_freq.keys(),arcs_freq.values())]

# %%
edges
# Out:
# [('SBFL', 'SBCT', 76),
#  ('SBBR', 'SBRF', 1145),
#  ('SBFL', 'SBSV', 17),
#  ('SBCF', 'SBRJ', 2837),
#  ('SBPA', 'SBGR', 3628),
#  ('SBKP', 'SBCT', 1792),
#  ('SBSV', 'SBGR', 1798),
#  ('SBGR', 'SBPA', 4021),
#  ('SBSV', 'SBFL', 17),
#  ('SBSP', 'SBGR', 15),
#  ('SBRF', 'SBGL', 515),
#  ('SBRJ', 'SBCT', 1673),
#  ('SBGL', 'SBPA', 24),
#  ('SBCF', 'SBPA', 499),
#  ('SBRJ', 'SBSV', 1691),
#  ('SBPA', 'SBBR', 1063),
#  ('SBCF', 'SBRF', 842),
#  ('SBCT', 'SBGR', 3065),
#  ('SBBR', 'SBGR', 2626),
#  ('SBFL', 'SBPA', 454),
#  ('SBPA', 'SBGL', 26),
#  ('SBSV', 'SBBR', 1125),
#  ('SBSP', 'SBBR', 4408),
#  ('SBSV', 'SBSP', 2883),
#  ('SBGR', 'SBKP', 36),
#  ('SBGL', 'SBKP', 965),
#  ('SBKP', 'SBPA', 2093),
#  ('SBCT', 'SBBR', 926),
#  ('SBCF', 'SBKP', 2264),
#  ('SBBR', 'SBSP', 4370),
#  ('SBGL', 'SBFL', 28),
#  ('SBCF', 'SBFL', 261),
#  ('SBFL', 'SBKP', 1128),
#  ('SBPA', 'SBCT', 1308),
#  ('SBRF', 'SBRJ', 914),
#  ('SBPA', 'SBSV', 82),
#  ('SBGR', 'SBRJ', 3023),
#  ('SBGL', 'SBRJ', 94),
#  ('SBSP', 'SBCT', 3537),
#  ('SBGL', 'SBCF', 83),
#  ('SBSP', 'SBSV', 2860),
#  ('SBCF', 'SBSP', 4757),
#  ('SBRF', 'SBPA', 82),
#  ('SBFL', 'SBRJ', 1066),
#  ('SBCT', 'SBSV', 32),
#  ('SBBR', 'SBSV', 1098),
#  ('SBGR', 'SBRF', 3097),
#  ('SBGL', 'SBRF', 812),
#  ('SBKP', 'SBRJ', 2888),
#  ('SBKP', 'SBCF', 2351),
#  ('SBFL', 'SBRF', 18),
#  ('SBRF', 'SBKP', 1170),
#  ('SBSV', 'SBGL', 142),
#  ('SBSP', 'SBGL', 23),
#  ('SBRF', 'SBFL', 19),
#  ('SBSP', 'SBRF', 2359),
#  ('SBGR', 'SBFL', 1880),
#  ('SBKP', 'SBRF', 1217),
#  ('SBRJ', 'SBPA', 2210),
#  ('SBPA', 'SBKP', 1990),
#  ('SBGL', 'SBGR', 1736),
#  ('SBBR', 'SBGL', 537),
#  ('SBCT', 'SBGL', 16),
#  ('SBCF', 'SBGR', 3621),
#  ('SBRF', 'SBCF', 1083),
#  ('SBRF', 'SBSP', 2437),
#  ('SBGR', 'SBCF', 3523),
#  ('SBSV', 'SBCT', 33),
#  ('SBGL', 'SBBR', 564),
#  ('SBGR', 'SBSP', 129),
#  ('SBCF', 'SBBR', 2279),
#  ('SBGL', 'SBSP', 160),
#  ('SBPA', 'SBRJ', 1907),
#  ('SBRJ', 'SBKP', 2539),
#  ('SBKP', 'SBFL', 1226),
#  ('SBKP', 'SBGR', 29),
#  ('SBBR', 'SBCT', 824),
#  ('SBFL', 'SBCF', 262),
#  ('SBRJ', 'SBFL', 1086),
#  ('SBSP', 'SBRJ', 11196),
#  ('SBFL', 'SBSP', 2795),
#  ('SBKP', 'SBBR', 2026),
#  ('SBCT', 'SBRJ', 1688),
#  ('SBPA', 'SBRF', 186),
#  ('SBSV', 'SBPA', 77),
#  ('SBKP', 'SBSP', 29),
#  ('SBSP', 'SBPA', 4561),
#  ('SBRJ', 'SBCF', 2710),
#  ('SBGL', 'SBCT', 25),
#  ('SBRJ', 'SBSP', 10632),
#  ('SBCF', 'SBCT', 626),
#  ('SBGL', 'SBSV', 174),
#  ('SBRF', 'SBGR', 3287),
#  ('SBCF', 'SBSV', 1484),
#  ('SBCT', 'SBPA', 1179),
#  ('SBBR', 'SBPA', 948),
#  ('SBRJ', 'SBRF', 846),
#  ('SBPA', 'SBFL', 446),
#  ('SBSV', 'SBKP', 1150),
#  ('SBSP', 'SBKP', 16),
#  ('SBRF', 'SBBR', 1352),
#  ('SBFL', 'SBGR', 1922),
#  ('SBGR', 'SBBR', 2780),
#  ('SBSP', 'SBFL', 2738),
#  ('SBKP', 'SBSV', 1406),
#  ('SBCT', 'SBKP', 1737),
#  ('SBBR', 'SBKP', 1869),
#  ('SBGR', 'SBGL', 1814),
#  ('SBPA', 'SBCF', 501),
#  ('SBCF', 'SBGL', 28),
#  ('SBCT', 'SBFL', 78),
#  ('SBBR', 'SBFL', 280),
#  ('SBFL', 'SBBR', 532),
#  ('SBPA', 'SBSP', 4631),
#  ('SBSV', 'SBRJ', 1342),
#  ('SBRJ', 'SBGR', 3029),
#  ('SBSV', 'SBCF', 1226),
#  ('SBSP', 'SBCF', 4699),
#  ('SBFL', 'SBGL', 18),
#  ('SBBR', 'SBRJ', 3286),
#  ('SBCT', 'SBCF', 645),
#  ('SBBR', 'SBCF', 2256),
#  ('SBRJ', 'SBBR', 3629),
#  ('SBGR', 'SBCT', 3296),
#  ('SBRF', 'SBSV', 1484),
#  ('SBCT', 'SBSP', 3329),
#  ('SBKP', 'SBGL', 1024),
#  ('SBSV', 'SBRF', 1280),
#  ('SBGR', 'SBSV', 1973)]

# %%
G= nx.DiGraph()

# %%
G_topo = nx.Graph()

# %%
G_topo.add_weighted_edges_from(edges)

# %%
G.add_weighted_edges_from(edges)

# %%
nx.draw(G,with_labels=True)

# %%
import matplotlib.pyplot as plt
pos=nx.spring_layout(G) # pos = nx.nx_agraph.graphviz_layout(G)
nx.draw_networkx(G,pos)
labels = nx.get_edge_attributes(G,'weight')
nx.draw_networkx_edge_labels(G,pos,edge_labels=labels)
# Out:
# {('SBFL', 'SBCT'): Text(-0.23074428252574386, 0.23090237158690163, '76'),
#  ('SBFL', 'SBSV'): Text(-0.21092844872478078, 0.4664480324346343, '17'),
#  ('SBFL', 'SBPA'): Text(-0.06241198838186257, 0.675046532618802, '454'),
#  ('SBFL', 'SBKP'): Text(0.20869874836865931, 0.5188302523372159, '1128'),
#  ('SBFL', 'SBRJ'): Text(-0.07735746337531801, 0.37046534167367207, '1066'),
#  ('SBFL', 'SBRF'): Text(0.30879386950200804, 0.31354179221034073, '18'),
#  ('SBFL', 'SBCF'): Text(0.1439664686205402, 0.20932873364780913, '262'),
#  ('SBFL', 'SBSP'): Text(-0.00025217499885576977, 0.41151962477198145, '2795'),
#  ('SBFL', 'SBGR'): Text(0.17316589536271532, 0.4139456564535984, '1922'),
#  ('SBFL', 'SBBR'): Text(0.03846144924946726, 0.15113894979189135, '532'),
#  ('SBFL', 'SBGL'): Text(0.5879290844606386, 0.15992670664727493, '18'),
#  ('SBCT', 'SBGR'): Text(-0.2334438710566491, -0.1393702033152382, '3065'),
#  ('SBCT', 'SBBR'): Text(-0.3681324536537892, -0.40218049655297605, '926'),
#  ('SBCT', 'SBSV'): Text(-0.6175352528177397, -0.08686526082937485, '32'),
#  ('SBCT', 'SBGL'): Text(0.18132265674718728, -0.3933874507711644, '16'),
#  ('SBCT', 'SBRJ'): Text(-0.48395780863122806, -0.1828462293037474, '1688'),
#  ('SBCT', 'SBPA'): Text(-0.4690241626886883, 0.12173212748218143, '1179'),
#  ('SBCT', 'SBKP'): Text(-0.1979111013757373, -0.03448460249180474, '1737'),
#  ('SBCT', 'SBFL'): Text(-0.2307411270864551, 0.23090666555540418, '78'),
#  ('SBCT', 'SBCF'): Text(-0.2626374394139753, -0.3439858569358325, '645'),
#  ('SBCT', 'SBSP'): Text(-0.4068486959868841, -0.14178710065257483, '3329'),
#  ('SBBR', 'SBRF'): Text(0.17139452266178412, -0.31953007858142324, '1145'),
#  ('SBBR', 'SBGR'): Text(0.03576034486011381, -0.21914696438650394, '2626'),
#  ('SBBR', 'SBSP'): Text(-0.13765402384599545, -0.22155262989385893, '4370'),
#  ('SBBR', 'SBSV'): Text(-0.3483272286316652, -0.16664262840613875, '1098'),
#  ('SBBR', 'SBGL'): Text(0.45053863013425066, -0.4731571659926816, '537'),
#  ('SBBR', 'SBCT'): Text(-0.3681537890084352, -0.4021741745263804, '824'),
#  ('SBBR', 'SBPA'): Text(-0.19981945096477371, 0.04194874279711269, '948'),
#  ('SBBR', 'SBKP'): Text(0.07129483549093374, -0.11425736853154544, '1869'),
#  ('SBBR', 'SBFL'): Text(0.03845974559929344, 0.15113110010672837, '280'),
#  ('SBBR', 'SBRJ'): Text(-0.21476009073425328, -0.2626234326814647, '3286'),
#  ('SBBR', 'SBCF'): Text(0.006561374799040065, -0.4237578657185529, '2256'),
#  ('SBRF', 'SBGL'): Text(0.7208594040940708, -0.3107416124323671, '515'),
#  ('SBRF', 'SBRJ'): Text(0.055564740971021376, -0.10020613080703655, '914'),
#  ('SBRF', 'SBPA'): Text(0.07050746528191132, 0.2043769762982217, '82'),
#  ('SBRF', 'SBKP'): Text(0.3416279928886161, 0.048166982539673886, '1170'),
#  ('SBRF', 'SBFL'): Text(0.30878935874087876, 0.3135577634529463, '19'),
#  ('SBRF', 'SBCF'): Text(0.2768916272753079, -0.2613439638840318, '1083'),
#  ('SBRF', 'SBSP'): Text(0.13268662154202548, -0.05915008426238855, '2437'),
#  ('SBRF', 'SBGR'): Text(0.30609886035233425, -0.05672396055434448, '3287'),
#  ('SBRF', 'SBBR'): Text(0.17138787253107735, -0.319534073976952, '1352'),
#  ('SBRF', 'SBSV'): Text(-0.07801222161047128, -0.004218444369782026, '1484'),
#  ('SBSV', 'SBGR'): Text(-0.21363437700125165, 0.09617443024808603, '1798'),
#  ('SBSV', 'SBFL'): Text(-0.21093490888736421, 0.4664427250552683, '17'),
#  ('SBSV', 'SBBR'): Text(-0.3483369620305049, -0.16663032232562103, '1125'),
#  ('SBSV', 'SBSP'): Text(-0.38704664794408206, 0.09374857930669545, '2883'),
#  ('SBSV', 'SBGL'): Text(0.20113269481282559, -0.1578449845014166, '142'),
#  ('SBSV', 'SBCT'): Text(-0.6175355423053902, -0.08686870265869884, '33'),
#  ('SBSV', 'SBPA'): Text(-0.4492203215664683, 0.3572618604276365, '77'),
#  ('SBSV', 'SBKP'): Text(-0.17810422299968043, 0.20105889916738873, '1150'),
#  ('SBSV', 'SBRJ'): Text(-0.46415324842394423, 0.05268865636223863, '1342'),
#  ('SBSV', 'SBCF'): Text(-0.24282104934683257, -0.10844883937803385, '1226'),
#  ('SBSV', 'SBRF'): Text(-0.07798993565757284, -0.004225000597310569, '1280'),
#  ('SBCF', 'SBRJ'): Text(-0.10926396466189536, -0.20442386029538107, '2837'),
#  ('SBCF', 'SBPA'): Text(-0.0943137792973805, 0.1001469915930262, '499'),
#  ('SBCF', 'SBRF'): Text(0.27690226244296356, -0.26133723899264005, '842'),
#  ('SBCF', 'SBKP'): Text(0.17680308594477134, -0.05606263366034425, '2264'),
#  ('SBCF', 'SBFL'): Text(0.14396622075363052, 0.20932426593251408, '261'),
#  ('SBCF', 'SBSP'): Text(-0.032154176192303874, -0.1633604888992759, '4757'),
#  ('SBCF', 'SBGR'): Text(0.14127129939611693, -0.160944931520282, '3621'),
#  ('SBCF', 'SBBR'): Text(0.0065704815251055315, -0.4237528429227861, '2279'),
#  ('SBCF', 'SBCT'): Text(-0.2626373087228391, -0.3439858644618205, '626'),
#  ('SBCF', 'SBSV'): Text(-0.24283164678992752, -0.10844116167202278, '1484'),
#  ('SBCF', 'SBGL'): Text(0.5560379905673398, -0.41496606731396407, '28'),
#  ('SBRJ', 'SBCT'): Text(-0.48397085267228046, -0.18285809750794957, '1673'),
#  ('SBRJ', 'SBSV'): Text(-0.4641533608795103, 0.05268873717366118, '1691'),
#  ('SBRJ', 'SBPA'): Text(-0.31564262551640343, 0.26129136779951345, '2210'),
#  ('SBRJ', 'SBKP'): Text(-0.0445113218512696, 0.10508106292254105, '2539'),
#  ('SBRJ', 'SBFL'): Text(-0.07736376041720594, 0.37045505249260735, '1086'),
#  ('SBRJ', 'SBCF'): Text(-0.10924659765524347, -0.20443650407829828, '2710'),
#  ('SBRJ', 'SBSP'): Text(-0.2534820184035401, -0.0022414391370757514, '10632'),
#  ('SBRJ', 'SBRF'): Text(0.05557523558055588, -0.1002076774836792, '846'),
#  ('SBRJ', 'SBGR'): Text(-0.08006290061073806, 0.0001869697419244476, '3029'),
#  ('SBRJ', 'SBBR'): Text(-0.2147619661082958, -0.2626198813739181, '3629'),
#  ('SBPA', 'SBGR'): Text(-0.06511714522928358, 0.3047711084007929, '3628'),
#  ('SBPA', 'SBBR'): Text(-0.19982394800554792, 0.0419720971621621, '1063'),
#  ('SBPA', 'SBGL'): Text(0.3496474673789549, 0.0507505347966104, '26'),
#  ('SBPA', 'SBCT'): Text(-0.4690258407425928, 0.12172769972077957, '1308'),
#  ('SBPA', 'SBSV'): Text(-0.4492076298647586, 0.35727968712292113, '82'),
#  ('SBPA', 'SBKP'): Text(-0.0295846568274174, 0.40965759406773694, '1990'),
#  ('SBPA', 'SBRJ'): Text(-0.3156431920952023, 0.26127981642742104, '1907'),
#  ('SBPA', 'SBRF'): Text(0.07051116914189359, 0.20437336942572015, '186'),
#  ('SBPA', 'SBFL'): Text(-0.06243057753843351, 0.6750380155621354, '446'),
#  ('SBPA', 'SBCF'): Text(-0.09431812514753068, 0.10015679804795197, '501'),
#  ('SBPA', 'SBSP'): Text(-0.2385354406988307, 0.3023491015596089, '4631'),
#  ('SBGR', 'SBPA'): Text(-0.06511566894489507, 0.30476947225914874, '4021'),
#  ('SBGR', 'SBKP'): Text(0.20600201175753052, 0.14855543181614306, '36'),
#  ('SBGR', 'SBRJ'): Text(-0.08004857143566779, 0.00018945690335991916, '3023'),
#  ('SBGR', 'SBRF'): Text(0.30609411963667, -0.056720451303363784, '3097'),
#  ('SBGR', 'SBFL'): Text(0.17316588428218815, 0.4139441341456882, '1880'),
#  ('SBGR', 'SBCF'): Text(0.1412711417241712, -0.16094603642038985, '3523'),
#  ('SBGR', 'SBSP'): Text(-0.0029415575298654684, 0.041247713119420215, '129'),
#  ('SBGR', 'SBBR'): Text(0.03577060173476454, -0.2191269532358716, '2780'),
#  ('SBGR', 'SBGL'): Text(0.5852331139376545, -0.21034604266463752, '1814'),
#  ('SBGR', 'SBCT'): Text(-0.23343178680943233, -0.13936472706345138, '3296'),
#  ('SBGR', 'SBSV'): Text(-0.2136192288647757, 0.09617235972082105, '1973'),
#  ('SBKP', 'SBCT'): Text(-0.19789918797568007, -0.03447679669066872, '1792'),
#  ('SBKP', 'SBPA'): Text(-0.029582788832097195, 0.4096565177884206, '2093'),
#  ('SBKP', 'SBRJ'): Text(-0.0445347816804722, 0.1050688949189591, '2888'),
#  ('SBKP', 'SBCF'): Text(0.1768047236901813, -0.056054803084111815, '2351'),
#  ('SBKP', 'SBRF'): Text(0.34163035561505195, 0.048162136798833854, '1217'),
#  ('SBKP', 'SBFL'): Text(0.20869839979090843, 0.5188330694582863, '1226'),
#  ('SBKP', 'SBGR'): Text(0.20600488814815487, 0.14856392245836458, '29'),
#  ('SBKP', 'SBBR'): Text(0.07130147961860889, -0.114243017894614, '2026'),
#  ('SBKP', 'SBSP'): Text(0.03258063629081387, 0.1461319614769918, '29'),
#  ('SBKP', 'SBSV'): Text(-0.17808401435168275, 0.20106142199773447, '1406'),
#  ('SBKP', 'SBGL'): Text(0.6207739678929391, -0.10546625118510267, '1024'),
#  ('SBSP', 'SBGR'): Text(-0.002953048512592593, 0.04124755241623235, '15'),
#  ('SBSP', 'SBBR'): Text(-0.13765116699260538, -0.2215718452711557, '4408'),
#  ('SBSP', 'SBCT'): Text(-0.40686309931267617, -0.1417983872687536, '3537'),
#  ('SBSP', 'SBSV'): Text(-0.38704309535542414, 0.09374765311957256, '2860'),
#  ('SBSP', 'SBGL'): Text(0.4118151518755695, -0.2127717861131848, '23'),
#  ('SBSP', 'SBRF'): Text(0.1326702210135, -0.05914488513795857, '2359'),
#  ('SBSP', 'SBRJ'): Text(-0.2534655910763449, -0.002232691760279071, '11196'),
#  ('SBSP', 'SBPA'): Text(-0.23853351090882702, 0.302340921557694, '4561'),
#  ('SBSP', 'SBKP'): Text(0.032590126181392565, 0.14613683525487653, '16'),
#  ('SBSP', 'SBFL'): Text(-0.0002521827897199458, 0.41151960828466616, '2738'),
#  ('SBSP', 'SBCF'): Text(-0.032139520120886944, -0.16338103658403513, '4699'),
#  ('SBGL', 'SBPA'): Text(0.34964895275135577, 0.05074935829235516, '24'),
#  ('SBGL', 'SBKP'): Text(0.6207621663172358, -0.1054550821113659, '965'),
#  ('SBGL', 'SBFL'): Text(0.5879319294887546, 0.15992239638103556, '28'),
#  ('SBGL', 'SBRJ'): Text(0.3347133426796085, -0.2538335423491649, '94'),
#  ('SBGL', 'SBCF'): Text(0.5560336848574381, -0.41496558819768403, '83'),
#  ('SBGL', 'SBRF'): Text(0.7208628101994232, -0.31074348699631726, '812'),
#  ('SBGL', 'SBGR'): Text(0.5852376517578559, -0.21034882182804693, '1736'),
#  ('SBGL', 'SBBR'): Text(0.450521550765117, -0.47315743920067005, '564'),
#  ('SBGL', 'SBSP'): Text(0.411819476386462, -0.21277363592213905, '160'),
#  ('SBGL', 'SBCT'): Text(0.18133091969122073, -0.39338816717850117, '25'),
#  ('SBGL', 'SBSV'): Text(0.2011429336256365, -0.1578489131006524, '174')}

# %%
nx.edge_betweenness_centrality(G)
# Out:
# {('SBFL', 'SBCT'): 0.008333333333333335,
#  ('SBFL', 'SBSV'): 0.007575757575757576,
#  ('SBFL', 'SBPA'): 0.007575757575757576,
#  ('SBFL', 'SBKP'): 0.007575757575757576,
#  ('SBFL', 'SBRJ'): 0.007575757575757576,
#  ('SBFL', 'SBRF'): 0.008333333333333335,
#  ('SBFL', 'SBCF'): 0.007575757575757576,
#  ('SBFL', 'SBSP'): 0.007575757575757576,
#  ('SBFL', 'SBGR'): 0.007575757575757576,
#  ('SBFL', 'SBBR'): 0.007575757575757576,
#  ('SBFL', 'SBGL'): 0.008333333333333335,
#  ('SBCT', 'SBGR'): 0.008333333333333335,
#  ('SBCT', 'SBBR'): 0.008333333333333335,
#  ('SBCT', 'SBSV'): 0.008333333333333335,
#  ('SBCT', 'SBGL'): 0.009090909090909092,
#  ('SBCT', 'SBRJ'): 0.008333333333333335,
#  ('SBCT', 'SBPA'): 0.008333333333333335,
#  ('SBCT', 'SBKP'): 0.008333333333333335,
#  ('SBCT', 'SBFL'): 0.008333333333333335,
#  ('SBCT', 'SBCF'): 0.008333333333333335,
#  ('SBCT', 'SBSP'): 0.008333333333333335,
#  ('SBBR', 'SBRF'): 0.008333333333333335,
#  ('SBBR', 'SBGR'): 0.007575757575757576,
#  ('SBBR', 'SBSP'): 0.007575757575757576,
#  ('SBBR', 'SBSV'): 0.007575757575757576,
#  ('SBBR', 'SBGL'): 0.008333333333333335,
#  ('SBBR', 'SBCT'): 0.008333333333333335,
#  ('SBBR', 'SBPA'): 0.007575757575757576,
#  ('SBBR', 'SBKP'): 0.007575757575757576,
#  ('SBBR', 'SBFL'): 0.007575757575757576,
#  ('SBBR', 'SBRJ'): 0.007575757575757576,
#  ('SBBR', 'SBCF'): 0.007575757575757576,
#  ('SBRF', 'SBGL'): 0.009090909090909092,
#  ('SBRF', 'SBRJ'): 0.008333333333333335,
#  ('SBRF', 'SBPA'): 0.008333333333333335,
#  ('SBRF', 'SBKP'): 0.008333333333333335,
#  ('SBRF', 'SBFL'): 0.008333333333333335,
#  ('SBRF', 'SBCF'): 0.008333333333333335,
#  ('SBRF', 'SBSP'): 0.008333333333333335,
#  ('SBRF', 'SBGR'): 0.008333333333333335,
#  ('SBRF', 'SBBR'): 0.008333333333333335,
#  ('SBRF', 'SBSV'): 0.008333333333333335,
#  ('SBSV', 'SBGR'): 0.007575757575757576,
#  ('SBSV', 'SBFL'): 0.007575757575757576,
#  ('SBSV', 'SBBR'): 0.007575757575757576,
#  ('SBSV', 'SBSP'): 0.007575757575757576,
#  ('SBSV', 'SBGL'): 0.008333333333333335,
#  ('SBSV', 'SBCT'): 0.008333333333333335,
#  ('SBSV', 'SBPA'): 0.007575757575757576,
#  ('SBSV', 'SBKP'): 0.007575757575757576,
#  ('SBSV', 'SBRJ'): 0.007575757575757576,
#  ('SBSV', 'SBCF'): 0.007575757575757576,
#  ('SBSV', 'SBRF'): 0.008333333333333335,
#  ('SBCF', 'SBRJ'): 0.007575757575757576,
#  ('SBCF', 'SBPA'): 0.007575757575757576,
#  ('SBCF', 'SBRF'): 0.008333333333333335,
#  ('SBCF', 'SBKP'): 0.007575757575757576,
#  ('SBCF', 'SBFL'): 0.007575757575757576,
#  ('SBCF', 'SBSP'): 0.007575757575757576,
#  ('SBCF', 'SBGR'): 0.007575757575757576,
#  ('SBCF', 'SBBR'): 0.007575757575757576,
#  ('SBCF', 'SBCT'): 0.008333333333333335,
#  ('SBCF', 'SBSV'): 0.007575757575757576,
#  ('SBCF', 'SBGL'): 0.008333333333333335,
#  ('SBRJ', 'SBCT'): 0.009090909090909092,
#  ('SBRJ', 'SBSV'): 0.008333333333333335,
#  ('SBRJ', 'SBPA'): 0.008333333333333335,
#  ('SBRJ', 'SBKP'): 0.008333333333333335,
#  ('SBRJ', 'SBFL'): 0.008333333333333335,
#  ('SBRJ', 'SBCF'): 0.008333333333333335,
#  ('SBRJ', 'SBSP'): 0.008333333333333335,
#  ('SBRJ', 'SBRF'): 0.009090909090909092,
#  ('SBRJ', 'SBGR'): 0.008333333333333335,
#  ('SBRJ', 'SBBR'): 0.008333333333333335,
#  ('SBPA', 'SBGR'): 0.007575757575757576,
#  ('SBPA', 'SBBR'): 0.007575757575757576,
#  ('SBPA', 'SBGL'): 0.008333333333333335,
#  ('SBPA', 'SBCT'): 0.008333333333333335,
#  ('SBPA', 'SBSV'): 0.007575757575757576,
#  ('SBPA', 'SBKP'): 0.007575757575757576,
#  ('SBPA', 'SBRJ'): 0.007575757575757576,
#  ('SBPA', 'SBRF'): 0.008333333333333335,
#  ('SBPA', 'SBFL'): 0.007575757575757576,
#  ('SBPA', 'SBCF'): 0.007575757575757576,
#  ('SBPA', 'SBSP'): 0.007575757575757576,
#  ('SBGR', 'SBPA'): 0.007575757575757576,
#  ('SBGR', 'SBKP'): 0.007575757575757576,
#  ('SBGR', 'SBRJ'): 0.007575757575757576,
#  ('SBGR', 'SBRF'): 0.008333333333333335,
#  ('SBGR', 'SBFL'): 0.007575757575757576,
#  ('SBGR', 'SBCF'): 0.007575757575757576,
#  ('SBGR', 'SBSP'): 0.007575757575757576,
#  ('SBGR', 'SBBR'): 0.007575757575757576,
#  ('SBGR', 'SBGL'): 0.008333333333333335,
#  ('SBGR', 'SBCT'): 0.008333333333333335,
#  ('SBGR', 'SBSV'): 0.007575757575757576,
#  ('SBKP', 'SBCT'): 0.008333333333333335,
#  ('SBKP', 'SBPA'): 0.007575757575757576,
#  ('SBKP', 'SBRJ'): 0.007575757575757576,
#  ('SBKP', 'SBCF'): 0.007575757575757576,
#  ('SBKP', 'SBRF'): 0.008333333333333335,
#  ('SBKP', 'SBFL'): 0.007575757575757576,
#  ('SBKP', 'SBGR'): 0.007575757575757576,
#  ('SBKP', 'SBBR'): 0.007575757575757576,
#  ('SBKP', 'SBSP'): 0.007575757575757576,
#  ('SBKP', 'SBSV'): 0.007575757575757576,
#  ('SBKP', 'SBGL'): 0.008333333333333335,
#  ('SBSP', 'SBGR'): 0.007575757575757576,
#  ('SBSP', 'SBBR'): 0.007575757575757576,
#  ('SBSP', 'SBCT'): 0.008333333333333335,
#  ('SBSP', 'SBSV'): 0.007575757575757576,
#  ('SBSP', 'SBGL'): 0.008333333333333335,
#  ('SBSP', 'SBRF'): 0.008333333333333335,
#  ('SBSP', 'SBRJ'): 0.007575757575757576,
#  ('SBSP', 'SBPA'): 0.007575757575757576,
#  ('SBSP', 'SBKP'): 0.007575757575757576,
#  ('SBSP', 'SBFL'): 0.007575757575757576,
#  ('SBSP', 'SBCF'): 0.007575757575757576,
#  ('SBGL', 'SBPA'): 0.007575757575757576,
#  ('SBGL', 'SBKP'): 0.007575757575757576,
#  ('SBGL', 'SBFL'): 0.007575757575757576,
#  ('SBGL', 'SBRJ'): 0.007575757575757576,
#  ('SBGL', 'SBCF'): 0.007575757575757576,
#  ('SBGL', 'SBRF'): 0.008333333333333335,
#  ('SBGL', 'SBGR'): 0.007575757575757576,
#  ('SBGL', 'SBBR'): 0.007575757575757576,
#  ('SBGL', 'SBSP'): 0.007575757575757576,
#  ('SBGL', 'SBCT'): 0.008333333333333335,
#  ('SBGL', 'SBSV'): 0.007575757575757576}

# %%
nx.edge_load_centrality(G)
# Out:
# {('SBFL', 'SBCT'): 13.0,
#  ('SBCT', 'SBFL'): 13.0,
#  ('SBFL', 'SBSV'): 12.0,
#  ('SBSV', 'SBFL'): 12.0,
#  ('SBFL', 'SBPA'): 12.0,
#  ('SBPA', 'SBFL'): 12.0,
#  ('SBFL', 'SBKP'): 12.0,
#  ('SBKP', 'SBFL'): 12.0,
#  ('SBFL', 'SBRJ'): 13.0,
#  ('SBRJ', 'SBFL'): 13.0,
#  ('SBFL', 'SBRF'): 13.0,
#  ('SBRF', 'SBFL'): 13.0,
#  ('SBFL', 'SBCF'): 12.0,
#  ('SBCF', 'SBFL'): 12.0,
#  ('SBFL', 'SBSP'): 12.0,
#  ('SBSP', 'SBFL'): 12.0,
#  ('SBFL', 'SBGR'): 12.0,
#  ('SBGR', 'SBFL'): 12.0,
#  ('SBFL', 'SBBR'): 12.0,
#  ('SBBR', 'SBFL'): 12.0,
#  ('SBFL', 'SBGL'): 12.0,
#  ('SBGL', 'SBFL'): 12.0,
#  ('SBCT', 'SBGR'): 13.0,
#  ('SBGR', 'SBCT'): 13.0,
#  ('SBCT', 'SBBR'): 13.0,
#  ('SBBR', 'SBCT'): 13.0,
#  ('SBCT', 'SBSV'): 13.0,
#  ('SBSV', 'SBCT'): 13.0,
#  ('SBCT', 'SBGL'): 13.0,
#  ('SBGL', 'SBCT'): 13.0,
#  ('SBCT', 'SBRJ'): 14.0,
#  ('SBRJ', 'SBCT'): 14.0,
#  ('SBCT', 'SBPA'): 13.0,
#  ('SBPA', 'SBCT'): 13.0,
#  ('SBCT', 'SBKP'): 13.0,
#  ('SBKP', 'SBCT'): 13.0,
#  ('SBCT', 'SBCF'): 13.0,
#  ('SBCF', 'SBCT'): 13.0,
#  ('SBCT', 'SBSP'): 13.0,
#  ('SBSP', 'SBCT'): 13.0,
#  ('SBBR', 'SBRF'): 13.0,
#  ('SBRF', 'SBBR'): 13.0,
#  ('SBBR', 'SBGR'): 12.0,
#  ('SBGR', 'SBBR'): 12.0,
#  ('SBBR', 'SBSP'): 12.0,
#  ('SBSP', 'SBBR'): 12.0,
#  ('SBBR', 'SBSV'): 12.0,
#  ('SBSV', 'SBBR'): 12.0,
#  ('SBBR', 'SBGL'): 12.0,
#  ('SBGL', 'SBBR'): 12.0,
#  ('SBBR', 'SBPA'): 12.0,
#  ('SBPA', 'SBBR'): 12.0,
#  ('SBBR', 'SBKP'): 12.0,
#  ('SBKP', 'SBBR'): 12.0,
#  ('SBBR', 'SBRJ'): 13.0,
#  ('SBRJ', 'SBBR'): 13.0,
#  ('SBBR', 'SBCF'): 12.0,
#  ('SBCF', 'SBBR'): 12.0,
#  ('SBRF', 'SBGL'): 13.0,
#  ('SBGL', 'SBRF'): 13.0,
#  ('SBRF', 'SBRJ'): 14.0,
#  ('SBRJ', 'SBRF'): 14.0,
#  ('SBRF', 'SBPA'): 13.0,
#  ('SBPA', 'SBRF'): 13.0,
#  ('SBRF', 'SBKP'): 13.0,
#  ('SBKP', 'SBRF'): 13.0,
#  ('SBRF', 'SBCF'): 13.0,
#  ('SBCF', 'SBRF'): 13.0,
#  ('SBRF', 'SBSP'): 13.0,
#  ('SBSP', 'SBRF'): 13.0,
#  ('SBRF', 'SBGR'): 13.0,
#  ('SBGR', 'SBRF'): 13.0,
#  ('SBRF', 'SBSV'): 13.0,
#  ('SBSV', 'SBRF'): 13.0,
#  ('SBSV', 'SBGR'): 12.0,
#  ('SBGR', 'SBSV'): 12.0,
#  ('SBSV', 'SBSP'): 12.0,
#  ('SBSP', 'SBSV'): 12.0,
#  ('SBSV', 'SBGL'): 12.0,
#  ('SBGL', 'SBSV'): 12.0,
#  ('SBSV', 'SBPA'): 12.0,
#  ('SBPA', 'SBSV'): 12.0,
#  ('SBSV', 'SBKP'): 12.0,
#  ('SBKP', 'SBSV'): 12.0,
#  ('SBSV', 'SBRJ'): 13.0,
#  ('SBRJ', 'SBSV'): 13.0,
#  ('SBSV', 'SBCF'): 12.0,
#  ('SBCF', 'SBSV'): 12.0,
#  ('SBCF', 'SBRJ'): 13.0,
#  ('SBRJ', 'SBCF'): 13.0,
#  ('SBCF', 'SBPA'): 12.0,
#  ('SBPA', 'SBCF'): 12.0,
#  ('SBCF', 'SBKP'): 12.0,
#  ('SBKP', 'SBCF'): 12.0,
#  ('SBCF', 'SBSP'): 12.0,
#  ('SBSP', 'SBCF'): 12.0,
#  ('SBCF', 'SBGR'): 12.0,
#  ('SBGR', 'SBCF'): 12.0,
#  ('SBCF', 'SBGL'): 12.0,
#  ('SBGL', 'SBCF'): 12.0,
#  ('SBRJ', 'SBPA'): 13.0,
#  ('SBPA', 'SBRJ'): 13.0,
#  ('SBRJ', 'SBKP'): 13.0,
#  ('SBKP', 'SBRJ'): 13.0,
#  ('SBRJ', 'SBSP'): 13.0,
#  ('SBSP', 'SBRJ'): 13.0,
#  ('SBRJ', 'SBGR'): 13.0,
#  ('SBGR', 'SBRJ'): 13.0,
#  ('SBPA', 'SBGR'): 12.0,
#  ('SBGR', 'SBPA'): 12.0,
#  ('SBPA', 'SBGL'): 12.0,
#  ('SBGL', 'SBPA'): 12.0,
#  ('SBPA', 'SBKP'): 12.0,
#  ('SBKP', 'SBPA'): 12.0,
#  ('SBPA', 'SBSP'): 12.0,
#  ('SBSP', 'SBPA'): 12.0,
#  ('SBGR', 'SBKP'): 12.0,
#  ('SBKP', 'SBGR'): 12.0,
#  ('SBGR', 'SBSP'): 12.0,
#  ('SBSP', 'SBGR'): 12.0,
#  ('SBGR', 'SBGL'): 12.0,
#  ('SBGL', 'SBGR'): 12.0,
#  ('SBKP', 'SBSP'): 12.0,
#  ('SBSP', 'SBKP'): 12.0,
#  ('SBKP', 'SBGL'): 12.0,
#  ('SBGL', 'SBKP'): 12.0,
#  ('SBSP', 'SBGL'): 12.0,
#  ('SBGL', 'SBSP'): 12.0,
#  ('SBGL', 'SBRJ'): 12.0,
#  ('SBRJ', 'SBGL'): 12.0}

# %%
nx.edge_betweenness_centrality(G, weight='weight')
# Out:
# {('SBFL', 'SBCT'): 0.0,
#  ('SBFL', 'SBSV'): 0.07575757575757576,
#  ('SBFL', 'SBPA'): 0.0,
#  ('SBFL', 'SBKP'): 0.0,
#  ('SBFL', 'SBRJ'): 0.0,
#  ('SBFL', 'SBRF'): 0.07575757575757576,
#  ('SBFL', 'SBCF'): 0.0,
#  ('SBFL', 'SBSP'): 0.0,
#  ('SBFL', 'SBGR'): 0.0,
#  ('SBFL', 'SBBR'): 0.08333333333333334,
#  ('SBFL', 'SBGL'): 0.2878787878787879,
#  ('SBCT', 'SBGR'): 0.0,
#  ('SBCT', 'SBBR'): 0.0,
#  ('SBCT', 'SBSV'): 0.007575757575757576,
#  ('SBCT', 'SBGL'): 0.07575757575757576,
#  ('SBCT', 'SBRJ'): 0.0,
#  ('SBCT', 'SBPA'): 0.0,
#  ('SBCT', 'SBKP'): 0.0,
#  ('SBCT', 'SBFL'): 0.0,
#  ('SBCT', 'SBCF'): 0.0,
#  ('SBCT', 'SBSP'): 0.0,
#  ('SBBR', 'SBRF'): 0.0,
#  ('SBBR', 'SBGR'): 0.0,
#  ('SBBR', 'SBSP'): 0.0,
#  ('SBBR', 'SBSV'): 0.0,
#  ('SBBR', 'SBGL'): 0.0,
#  ('SBBR', 'SBCT'): 0.0,
#  ('SBBR', 'SBPA'): 0.0,
#  ('SBBR', 'SBKP'): 0.0,
#  ('SBBR', 'SBFL'): 0.08333333333333334,
#  ('SBBR', 'SBRJ'): 0.0,
#  ('SBBR', 'SBCF'): 0.0,
#  ('SBRF', 'SBGL'): 0.0,
#  ('SBRF', 'SBRJ'): 0.0,
#  ('SBRF', 'SBPA'): 0.0,
#  ('SBRF', 'SBKP'): 0.0,
#  ('SBRF', 'SBFL'): 0.1590909090909091,
#  ('SBRF', 'SBCF'): 0.0,
#  ('SBRF', 'SBSP'): 0.0,
#  ('SBRF', 'SBGR'): 0.0,
#  ('SBRF', 'SBBR'): 0.0,
#  ('SBRF', 'SBSV'): 0.0,
#  ('SBSV', 'SBGR'): 0.0,
#  ('SBSV', 'SBFL'): 0.07575757575757576,
#  ('SBSV', 'SBBR'): 0.0,
#  ('SBSV', 'SBSP'): 0.0,
#  ('SBSV', 'SBGL'): 0.0,
#  ('SBSV', 'SBCT'): 0.007575757575757576,
#  ('SBSV', 'SBPA'): 0.0,
#  ('SBSV', 'SBKP'): 0.0,
#  ('SBSV', 'SBRJ'): 0.0,
#  ('SBSV', 'SBCF'): 0.0,
#  ('SBSV', 'SBRF'): 0.0,
#  ('SBCF', 'SBRJ'): 0.0,
#  ('SBCF', 'SBPA'): 0.0,
#  ('SBCF', 'SBRF'): 0.0,
#  ('SBCF', 'SBKP'): 0.0,
#  ('SBCF', 'SBFL'): 0.0,
#  ('SBCF', 'SBSP'): 0.0,
#  ('SBCF', 'SBGR'): 0.0,
#  ('SBCF', 'SBBR'): 0.0,
#  ('SBCF', 'SBCT'): 0.0,
#  ('SBCF', 'SBSV'): 0.0,
#  ('SBCF', 'SBGL'): 0.08333333333333334,
#  ('SBRJ', 'SBCT'): 0.0,
#  ('SBRJ', 'SBSV'): 0.0,
#  ('SBRJ', 'SBPA'): 0.0,
#  ('SBRJ', 'SBKP'): 0.0,
#  ('SBRJ', 'SBFL'): 0.0,
#  ('SBRJ', 'SBCF'): 0.0,
#  ('SBRJ', 'SBSP'): 0.0,
#  ('SBRJ', 'SBRF'): 0.08333333333333334,
#  ('SBRJ', 'SBGR'): 0.0,
#  ('SBRJ', 'SBBR'): 0.0,
#  ('SBPA', 'SBGR'): 0.0,
#  ('SBPA', 'SBBR'): 0.0,
#  ('SBPA', 'SBGL'): 0.08333333333333334,
#  ('SBPA', 'SBCT'): 0.0,
#  ('SBPA', 'SBSV'): 0.0,
#  ('SBPA', 'SBKP'): 0.0,
#  ('SBPA', 'SBRJ'): 0.0,
#  ('SBPA', 'SBRF'): 0.0,
#  ('SBPA', 'SBFL'): 0.0,
#  ('SBPA', 'SBCF'): 0.0,
#  ('SBPA', 'SBSP'): 0.0,
#  ('SBGR', 'SBPA'): 0.0,
#  ('SBGR', 'SBKP'): 0.08333333333333334,
#  ('SBGR', 'SBRJ'): 0.0,
#  ('SBGR', 'SBRF'): 0.0,
#  ('SBGR', 'SBFL'): 0.0,
#  ('SBGR', 'SBCF'): 0.0,
#  ('SBGR', 'SBSP'): 0.0,
#  ('SBGR', 'SBBR'): 0.0,
#  ('SBGR', 'SBGL'): 0.0,
#  ('SBGR', 'SBCT'): 0.0,
#  ('SBGR', 'SBSV'): 0.0,
#  ('SBKP', 'SBCT'): 0.0,
#  ('SBKP', 'SBPA'): 0.0,
#  ('SBKP', 'SBRJ'): 0.0,
#  ('SBKP', 'SBCF'): 0.0,
#  ('SBKP', 'SBRF'): 0.0,
#  ('SBKP', 'SBFL'): 0.0,
#  ('SBKP', 'SBGR'): 0.007575757575757576,
#  ('SBKP', 'SBBR'): 0.0,
#  ('SBKP', 'SBSP'): 0.15151515151515152,
#  ('SBKP', 'SBSV'): 0.0,
#  ('SBKP', 'SBGL'): 0.0,
#  ('SBSP', 'SBGR'): 0.07575757575757576,
#  ('SBSP', 'SBBR'): 0.0,
#  ('SBSP', 'SBCT'): 0.0,
#  ('SBSP', 'SBSV'): 0.0,
#  ('SBSP', 'SBGL'): 0.20454545454545456,
#  ('SBSP', 'SBRF'): 0.0,
#  ('SBSP', 'SBRJ'): 0.0,
#  ('SBSP', 'SBPA'): 0.0,
#  ('SBSP', 'SBKP'): 0.07575757575757576,
#  ('SBSP', 'SBFL'): 0.0,
#  ('SBSP', 'SBCF'): 0.0,
#  ('SBGL', 'SBPA'): 0.08333333333333334,
#  ('SBGL', 'SBKP'): 0.0,
#  ('SBGL', 'SBFL'): 0.20454545454545456,
#  ('SBGL', 'SBRJ'): 0.08333333333333334,
#  ('SBGL', 'SBCF'): 0.08333333333333334,
#  ('SBGL', 'SBRF'): 0.0,
#  ('SBGL', 'SBGR'): 0.0,
#  ('SBGL', 'SBBR'): 0.0,
#  ('SBGL', 'SBSP'): 0.20454545454545456,
#  ('SBGL', 'SBCT'): 0.07575757575757576,
#  ('SBGL', 'SBSV'): 0.0}

# %%
nx.google_matrix(G)[0,1]
# Out:
# 0.020294401544401545

# %%
nx.is_directed(G)
# Out:
# True

# %%
arr= nx.adjacency_matrix(G)

# %%
type(nx.edge_betweenness_centrality(G))
# Out:
# dict

# %%
from typing import Dict

# %%
def insert_graph_measure(df: pd.DataFrame, measure_dict: Dict, name_measure: str, directed:bool= True):

    df[name_measure] = pd.Series(dtype=float)

    for edge,measure_value in measure_dict.items():
        if directed:
            origem, destino = edge
            df.loc[(df.origem == origem) & (df.destino == destino), name_measure] = measure_value
        else:
            origem, destino = edge
            df.loc[(df.origem == origem) & (df.destino == destino) | (df.origem == destino) & (df.destino == origem), name_measure] = measure_value

# %%
G.nodes()
# Out:
# NodeView(('SBFL', 'SBCT', 'SBBR', 'SBRF', 'SBSV', 'SBCF', 'SBRJ', 'SBPA', 'SBGR', 'SBKP', 'SBSP', 'SBGL'))

# %%
import numpy as np
import networkx as nx
import pandas as pd


def insert_graph_measure(df: pd.DataFrame, measure_dict: Dict, name_measure: str, directed:bool= True):

    df[name_measure] = pd.Series(dtype=float)

    for edge,measure_value in measure_dict.items():
        if directed:
            origem, destino = edge
            df.loc[(df.origem == origem) & (df.destino == destino), name_measure] = measure_value
        else:
            origem, destino = edge
            df.loc[(df.origem == origem) & (df.destino == destino) | (df.origem == destino) & (df.destino == origem), name_measure] = measure_value



def generate_graph_features(df: pd.DataFrame):

    arcs = list(zip(df.origem,df.destino))

    arcs_freq= {x : arcs.count(x) for x in set(arcs)}


    G= nx.DiGraph()

    G_topo = nx.Graph()

    edges= [tuple(list(tup)+[val] )  for tup,val in zip(arcs_freq.keys(),arcs_freq.values())]

    G.add_weighted_edges_from(edges)

    G_topo.add_weighted_edges_from(edges)

    insert_graph_measure(df,nx.edge_betweenness_centrality(G), 'betwenness')    

    insert_graph_measure(df,nx.edge_current_flow_betweenness_centrality(G_topo),'flow_betweenness_topo',directed=False)

    df['edge_connectivity'] = pd.Series(dtype=float)

    df['deg_diff'] = pd.Series(dtype=float)

    for origem, destino, weight in edges:
        
        connec = nx.algorithms.connectivity.local_edge_connectivity(G, destino, origem)
        degdiff = G.degree(destino) - G.degree(origem)
        df.loc[(df.origem == origem) & (df.destino == destino), 'edge_connectivity'] = connec
        df.loc[(df.origem == origem) & (df.destino == destino), 'deg_diff'] = degdiff


    gmatrix= nx.google_matrix(G)

    df['gmatrix']= pd.Series(dtype=float)

    nodes= list(G.nodes())

    for i in range(len(nodes)):
        for j in range(len(nodes)):
            origem = nodes[i]
            destino = nodes[j]
            df.loc[(df.origem == origem) & (df.destino == destino), 'gmatrix'] = gmatrix[i][j]

#def graph_features_testdata(df: pd.DataFrame):

# %%
generate_graph_features(df)

# %%
df.head()
# Out:
#                            flightid              hora_ref origem destino  \
# 0  504a62621cd231d6ab67e674ce538cd3  2022-06-01T01:00:00Z   SBCF    SBFL
# 1  b0fd0f83644625ecc21f5261e8e5e347  2022-06-01T01:00:00Z   SBPA    SBFL
# 2  1210f0ca07ddca00d09a3e02d3b100d8  2022-06-01T01:00:00Z   SBSP    SBCF
# 3  b25032f34507cce285ee779446496568  2022-06-01T01:00:00Z   SBGR    SBCT
# 4  00762a9892ecba7c66d1d87800d38cac  2022-06-01T01:00:00Z   SBSP    SBSV
#
#                                     url_img_satelite metaf  \
# 0  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 1  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 2  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 3  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 4  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
#
#                                                metar  prev_troca_cabeceira  \
# 0  METAR SBFL 010000Z 17009KT 140V200 9999 BKN030...                     0
# 1  METAR SBFL 010000Z 17009KT 140V200 9999 BKN030...                     0
# 2      METAR SBCF 010000Z 12006KT CAVOK 21/14 Q1018=                     0
# 3  METAR SBCT 010000Z 10006KT 7000 -RA BKN004 OVC...                     0
# 4  METAR SBSV 010000Z 11008KT 9999 FEW023 27/21 Q...                     0
#
#    troca_cabeceira_hora_anterior  espera  betwenness  flow_betweenness_topo  \
# 0                              1     0.0    0.007576               0.016667
# 1                              1     0.0    0.007576               0.016667
# 2                              0     0.0    0.007576               0.016667
# 3                              0     0.0    0.008333               0.018182
# 4                              1     0.0    0.007576               0.016667
#
#    edge_connectivity  deg_diff   gmatrix
# 0               11.0       0.0  0.023878
# 1               11.0       0.0  0.036542
# 2               11.0       0.0  0.122193
# 3               10.0      -2.0  0.122057
# 4               11.0       0.0  0.079264

# %%
insert_graph_measure(df,nx.edge_betweenness_centrality(G), 'betwenness')

# %%
insert_graph_measure(df,nx.edge_current_flow_betweenness_centrality(G_topo),'flow_betweenness_topo',directed=False)

# %%
insert_graph_measure(df,nx.edge_load_centrality(G),'load_topo', directed=False)

# %%
list(nx.resource_allocation_index(G_topo))
# Out:
# [('SBCT', 'SBRF', 0.9090909090909093)]

# %%
df['betwenness']
# Out:
# 0         0.007576
# 1         0.007576
# 2         0.007576
# 3         0.008333
# 4         0.007576
#             ...
# 211674    0.008333
# 211675    0.008333
# 211676    0.007576
# 211677    0.008333
# 211678    0.007576
# Name: betwenness, Length: 211679, dtype: float64

# %%
df['flow_betweenness_topo']
# Out:
# 0         0.016667
# 1         0.016667
# 2         0.016667
# 3         0.018182
# 4         0.016667
#             ...
# 211674    0.018182
# 211675    0.018182
# 211676    0.016667
# 211677    0.016667
# 211678    0.016667
# Name: flow_betweenness_topo, Length: 211679, dtype: float64

# %%
import numpy as np

# %%
list(G.nodes())
# Out:
# ['SBFL',
#  'SBCT',
#  'SBBR',
#  'SBRF',
#  'SBSV',
#  'SBCF',
#  'SBRJ',
#  'SBPA',
#  'SBGR',
#  'SBKP',
#  'SBSP',
#  'SBGL']

# %%
np.argwhere(nx.to_numpy_array(G) == 0)
# Out:
# array([[ 0,  0],
#        [ 1,  1],
#        [ 1,  3],
#        [ 2,  2],
#        [ 3,  1],
#        [ 3,  3],
#        [ 4,  4],
#        [ 5,  5],
#        [ 6,  6],
#        [ 6, 11],
#        [ 7,  7],
#        [ 8,  8],
#        [ 9,  9],
#        [10, 10],
#        [11, 11]])

# %%
node_list = list(G.nodes())

# %%
for i in range(len(node_list)):
    print(node_list[i],i)
# Out:
# SBFL 0
# SBCT 1
# SBBR 2
# SBRF 3
# SBSV 4
# SBCF 5
# SBRJ 6
# SBPA 7
# SBGR 8
# SBKP 9
# SBSP 10
# SBGL 11

# %%
df.head()
# Out:
#                            flightid              hora_ref origem destino  \
# 0  504a62621cd231d6ab67e674ce538cd3  2022-06-01T01:00:00Z   SBCF    SBFL
# 1  b0fd0f83644625ecc21f5261e8e5e347  2022-06-01T01:00:00Z   SBPA    SBFL
# 2  1210f0ca07ddca00d09a3e02d3b100d8  2022-06-01T01:00:00Z   SBSP    SBCF
# 3  b25032f34507cce285ee779446496568  2022-06-01T01:00:00Z   SBGR    SBCT
# 4  00762a9892ecba7c66d1d87800d38cac  2022-06-01T01:00:00Z   SBSP    SBSV
#
#                                     url_img_satelite metaf  \
# 0  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 1  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 2  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 3  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
# 4  http://satelite.cptec.inpe.br/repositoriogoes/...   NaN
#
#                                                metar  prev_troca_cabeceira  \
# 0  METAR SBFL 010000Z 17009KT 140V200 9999 BKN030...                     0
# 1  METAR SBFL 010000Z 17009KT 140V200 9999 BKN030...                     0
# 2      METAR SBCF 010000Z 12006KT CAVOK 21/14 Q1018=                     0
# 3  METAR SBCT 010000Z 10006KT 7000 -RA BKN004 OVC...                     0
# 4  METAR SBSV 010000Z 11008KT 9999 FEW023 27/21 Q...                     0
#
#    troca_cabeceira_hora_anterior  espera  betwenness  flow_betweenness_topo  \
# 0                              1     0.0    0.007576               0.016667
# 1                              1     0.0    0.007576               0.016667
# 2                              0     0.0    0.007576               0.016667
# 3                              0     0.0    0.008333               0.018182
# 4                              1     0.0    0.007576               0.016667
#
#    edge_connectivity  deg_diff   gmatrix  load_topo
# 0               11.0       0.0  0.023878       12.0
# 1               11.0       0.0  0.036542       12.0
# 2               11.0       0.0  0.122193       12.0
# 3               10.0      -2.0  0.122057       13.0
# 4               11.0       0.0  0.079264       12.0

# %%
df.to_csv('flight_data.csv')
